# %% [markdown]
# ## Clova Face Recognition API를 이용한 데이터 점검 (성별, 나이) - (1)
# > 작성자: 유승리_T3129 / 작성일: 22.02.22.화
# - API를 이용하여 판단한 `age`와 `gender` (각각의 `confidence` 포함)
# - 데이터에 라벨링 되어있는 `age`와 `gender`

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import os
from pathlib import Path
import requests
import json 
import re
import pickle

pd.set_option('display.max_colwidth', 100)

# %% [markdown]
# ### 1. Data Pipeline for Learning
# - 규범님 코드입니다.
# - 경로가 다를 수 있으니 수정해서 사용하시면 됩니다.

# %%
train_df = pd.read_csv("../../input/data/train/train.csv")

# %%
def age_group(x):
    if x < 30:
        return 0
    elif x < 60:
        return 1
    else:
        return 2

def age_10(x):
    if x < 20:
        return 10
    elif x < 30:
        return 20
    elif x < 40:
        return 30
    elif x < 50:
        return 40
    elif x < 60:
        return 50
    else:
        return 60

def data_pipe(df: pd.DataFrame) -> pd.DataFrame:
    df["age_group"] = df["age"].apply(age_group)
    df["age_10"] = df["age"].apply(age_10)
    return df

# %%
train_df = data_pipe(train_df)

# %%
df = pd.DataFrame(None, columns = ['gender', 'age', 'age_group', 'age_10', 'mask', 'path', 'label'])
train_dir = '../../input/data/train/images'

# %%
for index, line in enumerate(train_df.iloc):
    for file in list(os.listdir(os.path.join(train_dir, line['path']))):
        if file[0] == '.':
            continue
        if file.split('.')[0] == 'normal':
            mask = 2
        elif file.split('.')[0] == 'incorrect_mask':
            mask = 1
        else:
            mask = 0
        gender = 0 if line['gender'] == 'male' else 1
        data = {
            'gender': gender,
            'age': line['age'],
            'age_group': line['age_group'],
            'age_10': line['age_10'],
            'mask': mask,
            'path': os.path.join(train_dir, line['path'], file),
            'label': mask * 6 + gender * 3 + line['age_group']
        }
        df = df.append(data, ignore_index=True)

# %%
df
# Out:
#       gender age age_group age_10 mask  \
# 0          1  45         1     40    0
# 1          1  45         1     40    0
# 2          1  45         1     40    0
# 3          1  45         1     40    0
# 4          1  45         1     40    1
# ...      ...  ..       ...    ...  ...
# 18895      0  19         0     10    0
# 18896      0  19         0     10    0
# 18897      0  19         0     10    1
# 18898      0  19         0     10    0
# 18899      0  19         0     10    2
#
#                                                                           path  \
# 0               ../../input/data/train/images/000001_female_Asian_45/mask1.jpg
# 1               ../../input/data/train/images/000001_female_Asian_45/mask4.jpg
# 2               ../../input/data/train/images/000001_female_Asian_45/mask3.jpg
# 3               ../../input/data/train/images/000001_female_Asian_45/mask5.jpg
# 4      ../../input/data/train/images/000001_female_Asian_45/incorrect_mask.jpg
# ...                                                                        ...
# 18895             ../../input/data/train/images/006959_male_Asian_19/mask3.jpg
# 18896             ../../input/data/train/images/006959_male_Asian_19/mask5.jpg
# 18897    ../../input/data/train/images/006959_male_Asian_19/incorrect_mask.jpg
# 18898             ../../input/data/train/images/006959_male_Asian_19/mask2.jpg
# 18899            ../../input/data/train/images/006959_male_Asian_19/normal.jpg
#
#       label
# 0         4
# 1         4
# 2         4
# 3         4
# 4        10
# ...     ...
# 18895     0
# 18896     0
# 18897     6
# 18898     0
# 18899    12
#
# [18900 rows x 7 columns]

# %%
# df.to_csv(os.path.join(train_dir, "../new_train.csv"))

df.to_csv("./new_train.csv") # 현재 위치에 저장

# %%
# 마스크를 쓰지 않은 데이터에 대해서만 dataframe 다시 만들기

is_not_mask = df['mask'] == 2

no_mask_df = df[is_not_mask]
no_mask_df.reset_index(drop=True, inplace=True)

no_mask_df
# Out:
#      gender age age_group age_10 mask  \
# 0         1  45         1     40    2
# 1         1  52         1     50    2
# 2         0  54         1     50    2
# 3         1  58         1     50    2
# 4         1  59         1     50    2
# ...     ...  ..       ...    ...  ...
# 2695      0  19         0     10    2
# 2696      0  19         0     10    2
# 2697      0  19         0     10    2
# 2698      0  20         0     20    2
# 2699      0  19         0     10    2
#
#                                                                  path label
# 0     ../../input/data/train/images/000001_female_Asian_45/normal.jpg    16
# 1     ../../input/data/train/images/000002_female_Asian_52/normal.jpg    16
# 2       ../../input/data/train/images/000004_male_Asian_54/normal.jpg    13
# 3     ../../input/data/train/images/000005_female_Asian_58/normal.jpg    16
# 4     ../../input/data/train/images/000006_female_Asian_59/normal.jpg    16
# ...                                                               ...   ...
# 2695    ../../input/data/train/images/006954_male_Asian_19/normal.jpg    12
# 2696    ../../input/data/train/images/006955_male_Asian_19/normal.jpg    12
# 2697    ../../input/data/train/images/006956_male_Asian_19/normal.jpg    12
# 2698    ../../input/data/train/images/006957_male_Asian_20/normal.jpg    12
# 2699    ../../input/data/train/images/006959_male_Asian_19/normal.jpg    12
#
# [2700 rows x 7 columns]

# %%
# 현재 위치에 dataframe 저장

with open( "./no_mask_df.pkl", "wb" ) as file:
    pickle.dump(no_mask_df, file)

# %% [markdown]
# ### 2. Clova Face Recognition API 적용해보기
# https://developers.naver.com/docs/clova/api/CFR/API_Guide.md#Preparation
# - 저장할 요소
#     - API 관련
#         - `age_api`
#         - `age_conf_api`
#         - `gender_api`
#         - `gender_conf_api`
#     - 데이터 라벨링 관련
#         - `age_data`
#         - `gender_data`
#         - `age_group_data`
#         - `label`
#         - `path`
# - 1000장 제한이 있으므로 다음과 같이 나눠 진행 예정 (총 0~2699, 2700장)
#     - `0222` - 2300~2699
#     - `0223` - 1300~2299
#     - `0224` - 300~1299
#     - `0225` - 0~299

# %%
# no_mask_df.pkl를 dataframe으로 불러오기 (1번에서 만들었으면 안해도 됨)

with open( "no_mask_df.pkl", "rb" ) as file:
    no_mask_df = pickle.load(file)
no_mask_df
# Out:
#      gender age age_group age_10 mask  \
# 0         1  45         1     40    2
# 1         1  52         1     50    2
# 2         0  54         1     50    2
# 3         1  58         1     50    2
# 4         1  59         1     50    2
# ...     ...  ..       ...    ...  ...
# 2695      0  19         0     10    2
# 2696      0  19         0     10    2
# 2697      0  19         0     10    2
# 2698      0  20         0     20    2
# 2699      0  19         0     10    2
#
#                                                                  path label
# 0     ../../input/data/train/images/000001_female_Asian_45/normal.jpg    16
# 1     ../../input/data/train/images/000002_female_Asian_52/normal.jpg    16
# 2       ../../input/data/train/images/000004_male_Asian_54/normal.jpg    13
# 3     ../../input/data/train/images/000005_female_Asian_58/normal.jpg    16
# 4     ../../input/data/train/images/000006_female_Asian_59/normal.jpg    16
# ...                                                               ...   ...
# 2695    ../../input/data/train/images/006954_male_Asian_19/normal.jpg    12
# 2696    ../../input/data/train/images/006955_male_Asian_19/normal.jpg    12
# 2697    ../../input/data/train/images/006956_male_Asian_19/normal.jpg    12
# 2698    ../../input/data/train/images/006957_male_Asian_20/normal.jpg    12
# 2699    ../../input/data/train/images/006959_male_Asian_19/normal.jpg    12
#
# [2700 rows x 7 columns]

# %%
compare_df = pd.DataFrame(None, columns = ['gender_data', 'gender_api', 'gender_conf_api', 
                                           'age_data', 'age_group_data', 'age_api', 'age_conf_api',
                                          'label', 'path'])

train_dir = '../../input/data/train/images'  # 환경에 맞게 수정 필요

# %%
# 사진 데이터 전체 

# 기록
## 02.22.화 - index 2300~2699 (계정 1)
## 02.23.수 - index 1300~2299 (계정 1)
## 02.23.수 - index 0300~1299 (계정 2)
## 02.23.수 - index 0000~0299 (계정 3)


cnt = 0  # gender가 다르게 인식된 개수

for index, line in enumerate(no_mask_df.iloc):
#     if index < 867 or index >= 1300:
#         continue
    if index >= 300:
        break

    client_id = "" #본인의 client id 
    client_secret = "" #본인의 client secret 
    
    url = "https://openapi.naver.com/v1/vision/face" # 얼굴감지
    age = 0
    files = {'image': open(line["path"], 'rb')} # open(directory/filename)
    headers = {'X-Naver-Client-Id': client_id, 'X-Naver-Client-Secret': client_secret }
    response = requests.post(url,  files=files, headers=headers)
    rescode = response.status_code
    # print(rescode) # 혹시 작동을 안하면 하루 최대 할당량 1000장을 넘었을 수도.. 그때 rescode = 42
    
    if(rescode==200):
        data = json.loads(response.text)
        ### 추가 ###
        _age_range = re.findall(r"\d+", data['faces'][0]['age']['value'])
        age_api = ((int(_age_range[0]) + int(_age_range[1])) / 2)
        age_conf_api = data['faces'][0]['age']['confidence']
        _gender = data['faces'][0]['gender']
        gender_api = 1 if _gender['value'] == 'female' else 0
        gender_conf_api = _gender['confidence']  
        ###########
        
        result = {
            'gender_data': line['gender'],
            'gender_api': gender_api,
            'gender_conf_api': gender_conf_api,
            'age_data': line['age'],
            'age_group_data': line['age_group'],
            'age_api': age_api,
            'age_conf_api': age_conf_api,
            'label': mask * 6 + gender * 3 + line['age_group'],
            'path': line['path'] #os.path.join(train_dir, line['path'], file),
        }
        compare_df = compare_df.append(result, ignore_index=True)
        
        # 성별 다른 경우에만 print 출력
        if gender_api != line['gender']:
            print("path: ", line["path"])
            print("age_data: ", line["age"])
            print("age_api: ", age_api)
            print("age_conf_api: ", age_conf_api)
            print("gender_data: ", line["gender"])
            print("gender_api: ", gender_api)
            print("gender_conf_api: ", gender_conf_api, '\n')
            cnt += 1

    else:
        print("Error Code:", rescode)
        print("Index:", index)
        break

print(f'end: 총 {cnt} 개')

# print 결과를 혹시 몰라 txt 파일에 복사 + 붙여넣기 해서 저장도 했음
# Out:
# path:  ../../input/data/train/images/000005_female_Asian_58/normal.jpg
# age_data:  58
# age_api:  66.0
# age_conf_api:  0.489103
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.999967
#
# path:  ../../input/data/train/images/000006_female_Asian_59/normal.jpg
# age_data:  59
# age_api:  60.0
# age_conf_api:  0.415534
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.746899
#
# path:  ../../input/data/train/images/000007_female_Asian_58/normal.jpg
# age_data:  58
# age_api:  67.0
# age_conf_api:  0.645071
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.698803
#
# path:  ../../input/data/train/images/000008_female_Asian_58/normal.jpg
# age_data:  58
# age_api:  74.0
# age_conf_api:  0.288556
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.999971
#
# path:  ../../input/data/train/images/000009_female_Asian_56/normal.jpg
# age_data:  56
# age_api:  70.0
# age_conf_api:  0.308341
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.999783
#
# path:  ../../input/data/train/images/000010_female_Asian_58/normal.jpg
# age_data:  58
# age_api:  68.0
# age_conf_api:  0.315771
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.999985
#
# path:  ../../input/data/train/images/000016_female_Asian_58/normal.jpg
# age_data:  58
# age_api:  71.0
# age_conf_api:  0.458813
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.999382
#
# path:  ../../input/data/train/images/000023_female_Asian_55/normal.jpg
# age_data:  55
# age_api:  54.0
# age_conf_api:  0.888096
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.995752
#
# path:  ../../input/data/train/images/000024_female_Asian_58/normal.jpg
# age_data:  58
# age_api:  58.0
# age_conf_api:  0.42292
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.995227
#
# path:  ../../input/data/train/images/000025_female_Asian_49/normal.jpg
# age_data:  49
# age_api:  66.0
# age_conf_api:  0.405667
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.998686
#
# path:  ../../input/data/train/images/000030_female_Asian_55/normal.jpg
# age_data:  55
# age_api:  66.0
# age_conf_api:  0.726654
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.803665
#
# path:  ../../input/data/train/images/000036_female_Asian_58/normal.jpg
# age_data:  58
# age_api:  69.0
# age_conf_api:  0.525489
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.996103
#
# path:  ../../input/data/train/images/000037_female_Asian_58/normal.jpg
# age_data:  58
# age_api:  82.0
# age_conf_api:  0.720672
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.997978
#
# path:  ../../input/data/train/images/000038_female_Asian_58/normal.jpg
# age_data:  58
# age_api:  66.0
# age_conf_api:  0.489605
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.999285
#
# path:  ../../input/data/train/images/000039_female_Asian_57/normal.jpg
# age_data:  57
# age_api:  83.0
# age_conf_api:  0.206002
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.999751
#
# path:  ../../input/data/train/images/000040_female_Asian_57/normal.jpg
# age_data:  57
# age_api:  59.0
# age_conf_api:  0.257782
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.999761
#
# path:  ../../input/data/train/images/000045_female_Asian_56/normal.jpg
# age_data:  56
# age_api:  68.0
# age_conf_api:  0.445588
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.804798
#
# path:  ../../input/data/train/images/000069_female_Asian_54/normal.jpg
# age_data:  54
# age_api:  54.0
# age_conf_api:  0.368186
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.998561
#
# path:  ../../input/data/train/images/000070_female_Asian_58/normal.jpg
# age_data:  58
# age_api:  71.0
# age_conf_api:  0.241322
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.985227
#
# path:  ../../input/data/train/images/000075_female_Asian_56/normal.jpg
# age_data:  56
# age_api:  64.0
# age_conf_api:  0.209334
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.810914
#
# path:  ../../input/data/train/images/000078_female_Asian_55/normal.jpg
# age_data:  55
# age_api:  61.0
# age_conf_api:  0.103604
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.997673
#
# path:  ../../input/data/train/images/000079_female_Asian_57/normal.jpg
# age_data:  57
# age_api:  70.0
# age_conf_api:  0.615386
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.528027
#
# path:  ../../input/data/train/images/000206_female_Asian_57/normal.jpg
# age_data:  57
# age_api:  77.0
# age_conf_api:  0.0513603
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.99996
#
# path:  ../../input/data/train/images/000207_female_Asian_56/normal.jpg
# age_data:  56
# age_api:  75.0
# age_conf_api:  0.0854086
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.995057
#
# path:  ../../input/data/train/images/000210_female_Asian_54/normal.jpg
# age_data:  54
# age_api:  66.0
# age_conf_api:  0.797089
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.999486
#
# path:  ../../input/data/train/images/000212_female_Asian_51/normal.jpg
# age_data:  51
# age_api:  73.0
# age_conf_api:  0.861208
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.999958
#
# path:  ../../input/data/train/images/000214_female_Asian_51/normal.jpg
# age_data:  51
# age_api:  68.0
# age_conf_api:  1.0
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.999986
#
# path:  ../../input/data/train/images/000215_female_Asian_59/normal.jpg
# age_data:  59
# age_api:  88.0
# age_conf_api:  0.534298
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.55741
#
# path:  ../../input/data/train/images/000216_female_Asian_56/normal.jpg
# age_data:  56
# age_api:  77.0
# age_conf_api:  0.252285
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.999896
#
# path:  ../../input/data/train/images/000219_female_Asian_53/normal.jpg
# age_data:  53
# age_api:  69.0
# age_conf_api:  1.0
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.830474
#
# path:  ../../input/data/train/images/000221_female_Asian_40/normal.jpg
# age_data:  40
# age_api:  69.0
# age_conf_api:  1.0
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.996692
#
# path:  ../../input/data/train/images/000226_female_Asian_58/normal.jpg
# age_data:  58
# age_api:  64.0
# age_conf_api:  0.167018
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.999998
#
# path:  ../../input/data/train/images/000227_female_Asian_59/normal.jpg
# age_data:  59
# age_api:  64.0
# age_conf_api:  0.583376
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.999846
#
# path:  ../../input/data/train/images/000228_female_Asian_56/normal.jpg
# age_data:  56
# age_api:  84.0
# age_conf_api:  0.306324
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.999223
#
# path:  ../../input/data/train/images/000243_female_Asian_58/normal.jpg
# age_data:  58
# age_api:  83.0
# age_conf_api:  0.584726
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.999865
#
# path:  ../../input/data/train/images/000244_female_Asian_56/normal.jpg
# age_data:  56
# age_api:  88.0
# age_conf_api:  0.314478
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.99477
#
# path:  ../../input/data/train/images/000261_female_Asian_58/normal.jpg
# age_data:  58
# age_api:  84.0
# age_conf_api:  0.235457
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.99995
#
# path:  ../../input/data/train/images/000263_female_Asian_48/normal.jpg
# age_data:  48
# age_api:  56.0
# age_conf_api:  1.0
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.761179
#
# path:  ../../input/data/train/images/000264_female_Asian_51/normal.jpg
# age_data:  51
# age_api:  74.0
# age_conf_api:  0.558363
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.994392
#
# path:  ../../input/data/train/images/000265_female_Asian_58/normal.jpg
# age_data:  58
# age_api:  82.0
# age_conf_api:  0.299313
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.998299
#
# path:  ../../input/data/train/images/000270_female_Asian_49/normal.jpg
# age_data:  49
# age_api:  72.0
# age_conf_api:  0.390297
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.998006
#
# path:  ../../input/data/train/images/000272_female_Asian_52/normal.jpg
# age_data:  52
# age_api:  80.0
# age_conf_api:  0.621656
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.992022
#
# path:  ../../input/data/train/images/000273_female_Asian_56/normal.jpg
# age_data:  56
# age_api:  81.0
# age_conf_api:  0.304034
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.999874
#
# path:  ../../input/data/train/images/000274_female_Asian_54/normal.jpg
# age_data:  54
# age_api:  68.0
# age_conf_api:  0.456001
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.549002
#
# path:  ../../input/data/train/images/000276_female_Asian_58/normal.jpg
# age_data:  58
# age_api:  71.0
# age_conf_api:  1.0
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.999587
#
# path:  ../../input/data/train/images/000277_female_Asian_54/normal.jpg
# age_data:  54
# age_api:  94.0
# age_conf_api:  0.652288
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.999353
#
# path:  ../../input/data/train/images/000278_female_Asian_54/normal.jpg
# age_data:  54
# age_api:  81.0
# age_conf_api:  0.688357
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.854889
#
# path:  ../../input/data/train/images/000279_female_Asian_54/normal.jpg
# age_data:  54
# age_api:  78.0
# age_conf_api:  0.293687
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.999988
#
# path:  ../../input/data/train/images/000280_female_Asian_54/normal.jpg
# age_data:  54
# age_api:  77.0
# age_conf_api:  0.163349
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.999992
#
# path:  ../../input/data/train/images/000282_female_Asian_59/normal.jpg
# age_data:  59
# age_api:  79.0
# age_conf_api:  0.302737
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.999753
#
# path:  ../../input/data/train/images/000283_female_Asian_57/normal.jpg
# age_data:  57
# age_api:  80.0
# age_conf_api:  0.289607
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.999864
#
# path:  ../../input/data/train/images/000286_female_Asian_51/normal.jpg
# age_data:  51
# age_api:  76.0
# age_conf_api:  0.465443
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.999969
#
# path:  ../../input/data/train/images/000288_female_Asian_51/normal.jpg
# age_data:  51
# age_api:  68.0
# age_conf_api:  0.457666
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.997557
#
# path:  ../../input/data/train/images/000292_female_Asian_57/normal.jpg
# age_data:  57
# age_api:  59.0
# age_conf_api:  0.4584
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.999138
#
# path:  ../../input/data/train/images/000293_female_Asian_57/normal.jpg
# age_data:  57
# age_api:  73.0
# age_conf_api:  0.58227
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.998924
#
# path:  ../../input/data/train/images/000295_female_Asian_56/normal.jpg
# age_data:  56
# age_api:  68.0
# age_conf_api:  0.772377
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.999045
#
# path:  ../../input/data/train/images/000299_female_Asian_57/normal.jpg
# age_data:  57
# age_api:  82.0
# age_conf_api:  0.38674
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.999992
#
# path:  ../../input/data/train/images/000311_female_Asian_58/normal.jpg
# age_data:  58
# age_api:  59.0
# age_conf_api:  1.0
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.999121
#
# path:  ../../input/data/train/images/000312_female_Asian_57/normal.jpg
# age_data:  57
# age_api:  70.0
# age_conf_api:  0.541189
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.980051
#
# path:  ../../input/data/train/images/000344_female_Asian_57/normal.jpg
# age_data:  57
# age_api:  79.0
# age_conf_api:  0.201395
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.997842
#
# path:  ../../input/data/train/images/000357_female_Asian_55/normal.jpg
# age_data:  55
# age_api:  70.0
# age_conf_api:  0.799117
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.999889
#
# path:  ../../input/data/train/images/000376_female_Asian_59/normal.jpg
# age_data:  59
# age_api:  74.0
# age_conf_api:  0.628131
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.999929
#
# path:  ../../input/data/train/images/000378_female_Asian_55/normal.jpg
# age_data:  55
# age_api:  74.0
# age_conf_api:  0.474307
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.997906
#
# path:  ../../input/data/train/images/000381_female_Asian_59/normal.jpg
# age_data:  59
# age_api:  89.0
# age_conf_api:  0.294745
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.999971
#
# path:  ../../input/data/train/images/000514_female_Asian_59/normal.jpg
# age_data:  59
# age_api:  82.0
# age_conf_api:  0.431291
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.999511
#
# path:  ../../input/data/train/images/000518_female_Asian_55/normal.jpg
# age_data:  55
# age_api:  85.0
# age_conf_api:  0.483187
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.536217
#
# path:  ../../input/data/train/images/000525_female_Asian_53/normal.jpg
# age_data:  53
# age_api:  65.0
# age_conf_api:  0.365887
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.632534
#
# path:  ../../input/data/train/images/000527_female_Asian_58/normal.jpg
# age_data:  58
# age_api:  87.0
# age_conf_api:  0.396419
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.781864
#
# path:  ../../input/data/train/images/000528_female_Asian_51/normal.jpg
# age_data:  51
# age_api:  81.0
# age_conf_api:  0.235746
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.537409
#
# path:  ../../input/data/train/images/000529_female_Asian_51/normal.jpg
# age_data:  51
# age_api:  61.0
# age_conf_api:  0.0592248
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.699314
#
# path:  ../../input/data/train/images/000533_female_Asian_54/normal.jpg
# age_data:  54
# age_api:  70.0
# age_conf_api:  0.683314
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.83558
#
# path:  ../../input/data/train/images/000535_female_Asian_50/normal.jpg
# age_data:  50
# age_api:  59.0
# age_conf_api:  0.876533
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.99865
#
# path:  ../../input/data/train/images/000539_female_Asian_54/normal.jpg
# age_data:  54
# age_api:  86.0
# age_conf_api:  0.539225
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.997106
#
# path:  ../../input/data/train/images/000561_female_Asian_52/normal.jpg
# age_data:  52
# age_api:  74.0
# age_conf_api:  0.466056
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.960354
#
# path:  ../../input/data/train/images/000562_female_Asian_58/normal.jpg
# age_data:  58
# age_api:  77.0
# age_conf_api:  0.359804
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.510095
#
# path:  ../../input/data/train/images/000564_female_Asian_57/normal.jpg
# age_data:  57
# age_api:  86.0
# age_conf_api:  0.785553
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.998727
#
# path:  ../../input/data/train/images/000567_female_Asian_51/normal.jpg
# age_data:  51
# age_api:  81.0
# age_conf_api:  0.447339
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.992368
#
# path:  ../../input/data/train/images/000568_female_Asian_54/normal.jpg
# age_data:  54
# age_api:  82.0
# age_conf_api:  0.314397
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.903345
#
# path:  ../../input/data/train/images/000572_female_Asian_57/normal.jpg
# age_data:  57
# age_api:  65.0
# age_conf_api:  0.847692
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.999278
#
# path:  ../../input/data/train/images/000601_female_Asian_53/normal.jpg
# age_data:  53
# age_api:  64.0
# age_conf_api:  0.535211
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.997099
#
# path:  ../../input/data/train/images/000602_female_Asian_50/normal.jpg
# age_data:  50
# age_api:  65.0
# age_conf_api:  0.302842
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.714984
#
# path:  ../../input/data/train/images/000610_female_Asian_52/normal.jpg
# age_data:  52
# age_api:  74.0
# age_conf_api:  0.0772124
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.577859
#
# path:  ../../input/data/train/images/000631_female_Asian_57/normal.jpg
# age_data:  57
# age_api:  88.0
# age_conf_api:  0.512146
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.783831
#
# path:  ../../input/data/train/images/000636_female_Asian_51/normal.jpg
# age_data:  51
# age_api:  65.0
# age_conf_api:  0.526634
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.531237
#
# path:  ../../input/data/train/images/000637_female_Asian_50/normal.jpg
# age_data:  50
# age_api:  62.0
# age_conf_api:  0.248168
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.980318
#
# path:  ../../input/data/train/images/000639_female_Asian_54/normal.jpg
# age_data:  54
# age_api:  88.0
# age_conf_api:  0.611952
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.994685
#
# path:  ../../input/data/train/images/000640_female_Asian_57/normal.jpg
# age_data:  57
# age_api:  65.0
# age_conf_api:  0.667686
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.991605
#
# path:  ../../input/data/train/images/000642_female_Asian_54/normal.jpg
# age_data:  54
# age_api:  81.0
# age_conf_api:  0.570466
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.955456
#
# path:  ../../input/data/train/images/000644_female_Asian_54/normal.jpg
# age_data:  54
# age_api:  73.0
# age_conf_api:  0.310518
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.990486
#
# path:  ../../input/data/train/images/000645_female_Asian_57/normal.jpg
# age_data:  57
# age_api:  68.0
# age_conf_api:  0.664949
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.999709
#
# path:  ../../input/data/train/images/000662_female_Asian_53/normal.jpg
# age_data:  53
# age_api:  74.0
# age_conf_api:  0.110769
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.999866
#
# path:  ../../input/data/train/images/000663_female_Asian_57/normal.jpg
# age_data:  57
# age_api:  73.0
# age_conf_api:  0.0578804
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.622202
#
# path:  ../../input/data/train/images/000664_female_Asian_55/normal.jpg
# age_data:  55
# age_api:  72.0
# age_conf_api:  0.581592
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.999946
#
# path:  ../../input/data/train/images/000667_female_Asian_57/normal.jpg
# age_data:  57
# age_api:  70.0
# age_conf_api:  0.35468
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.997569
#
# path:  ../../input/data/train/images/000668_female_Asian_53/normal.jpg
# age_data:  53
# age_api:  71.0
# age_conf_api:  0.201117
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.605021
#
# path:  ../../input/data/train/images/000686_female_Asian_52/normal.jpg
# age_data:  52
# age_api:  79.0
# age_conf_api:  0.431206
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.998228
#
# path:  ../../input/data/train/images/000693_female_Asian_54/normal.jpg
# age_data:  54
# age_api:  71.0
# age_conf_api:  0.385953
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.998974
#
# path:  ../../input/data/train/images/000696_female_Asian_58/normal.jpg
# age_data:  58
# age_api:  87.0
# age_conf_api:  0.363147
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.997685
#
# path:  ../../input/data/train/images/000698_female_Asian_55/normal.jpg
# age_data:  55
# age_api:  75.0
# age_conf_api:  0.284157
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.995671
#
# path:  ../../input/data/train/images/000717_female_Asian_51/normal.jpg
# age_data:  51
# age_api:  69.0
# age_conf_api:  0.793131
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.994398
#
# path:  ../../input/data/train/images/000718_female_Asian_56/normal.jpg
# age_data:  56
# age_api:  83.0
# age_conf_api:  0.493178
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.999453
#
# path:  ../../input/data/train/images/000719_female_Asian_53/normal.jpg
# age_data:  53
# age_api:  72.0
# age_conf_api:  0.128994
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.540524
#
# path:  ../../input/data/train/images/000720_female_Asian_56/normal.jpg
# age_data:  56
# age_api:  71.0
# age_conf_api:  0.552067
# gender_data:  1
# gender_api:  0
# gender_conf_api:  0.737737
#
# end: 총 103 개

# %%
compare_df
# Out:
#     gender_data gender_api  gender_conf_api age_data age_group_data  age_api  \
# 0             1          1         0.999806       45              1     53.0
# 1             1          1         0.508885       52              1     52.0
# 2             0          0         0.999874       54              1     45.0
# 3             1          0         0.999967       58              1     66.0
# 4             1          0         0.746899       59              1     60.0
# ..          ...        ...              ...      ...            ...      ...
# 295           1          0         0.994398       51              1     69.0
# 296           1          0         0.999453       56              1     83.0
# 297           1          0         0.540524       53              1     72.0
# 298           1          0         0.737737       56              1     71.0
# 299           1          1         0.995960       53              1     75.0
#
#      age_conf_api label  \
# 0        0.763184    13
# 1        0.987685    13
# 2        0.110434    13
# 3        0.489103    13
# 4        0.415534    13
# ..            ...   ...
# 295      0.793131    13
# 296      0.493178    13
# 297      0.128994    13
# 298      0.552067    13
# 299      0.236881    13
#
#                                                                 path
# 0    ../../input/data/train/images/000001_female_Asian_45/normal.jpg
# 1    ../../input/data/train/images/000002_female_Asian_52/normal.jpg
# 2      ../../input/data/train/images/000004_male_Asian_54/normal.jpg
# 3    ../../input/data/train/images/000005_female_Asian_58/normal.jpg
# 4    ../../input/data/train/images/000006_female_Asian_59/normal.jpg
# ..                                                               ...
# 295  ../../input/data/train/images/000717_female_Asian_51/normal.jpg
# 296  ../../input/data/train/images/000718_female_Asian_56/normal.jpg
# 297  ../../input/data/train/images/000719_female_Asian_53/normal.jpg
# 298  ../../input/data/train/images/000720_female_Asian_56/normal.jpg
# 299  ../../input/data/train/images/000721_female_Asian_53/normal.jpg
#
# [300 rows x 9 columns]

# %%
# 시각화를 하게 될 수도 있으니 dataframe을 pickle로 저장
# 파일 이름을 해당 인덱스로 바꾸기! ***

with open( "./0000-0299_naver-api.pkl", "wb" ) as file:
    pickle.dump(compare_df, file)

# %%
# 불러오기 실험
# with open( "./2300-2699_naver-api.pkl", "rb" ) as file:
#     loaded_data = pickle.load(file)
# loaded_data

# %% [markdown]
# ### no mask 데이터에 대해 저장한 dataframe 모두 합치기

# %%
with open( "./0000-0299_naver-api.pkl", "rb" ) as file:
    df_1 = pickle.load(file)
with open( "./0300-1299_naver-api.pkl", "rb" ) as file:
    df_2 = pickle.load(file)
with open( "./1300-2299_naver-api.pkl", "rb" ) as file:
    df_3 = pickle.load(file)
with open( "./2300-2699_naver-api.pkl", "rb" ) as file:
    df_4 = pickle.load(file)

print(df_1.shape)
print(df_2.shape)
print(df_3.shape)
print(df_4.shape)
# Out:
# (300, 9)
# (1000, 9)
# (1000, 9)
# (400, 9)

# %%
no_mask_api = pd.concat([df_1, df_2, df_3, df_4], ignore_index=True)
no_mask_api
# Out:
#      gender_data gender_api  gender_conf_api age_data age_group_data  age_api  \
# 0              1          1         0.999806       45              1     53.0
# 1              1          1         0.508885       52              1     52.0
# 2              0          0         0.999874       54              1     45.0
# 3              1          0         0.999967       58              1     66.0
# 4              1          0         0.746899       59              1     60.0
# ...          ...        ...              ...      ...            ...      ...
# 2695           0          0         0.999997       19              0     22.0
# 2696           0          0         0.999995       19              0     19.0
# 2697           0          0         0.999997       19              0     17.0
# 2698           0          0         0.995121       20              0     23.0
# 2699           0          0         0.999992       19              0     22.0
#
#       age_conf_api label  \
# 0         0.763184    13
# 1         0.987685    13
# 2         0.110434    13
# 3         0.489103    13
# 4         0.415534    13
# ...            ...   ...
# 2695      0.774581    12
# 2696      0.460716    12
# 2697      0.927676    12
# 2698      0.550162    12
# 2699      0.734206    12
#
#                                                                  path
# 0     ../../input/data/train/images/000001_female_Asian_45/normal.jpg
# 1     ../../input/data/train/images/000002_female_Asian_52/normal.jpg
# 2       ../../input/data/train/images/000004_male_Asian_54/normal.jpg
# 3     ../../input/data/train/images/000005_female_Asian_58/normal.jpg
# 4     ../../input/data/train/images/000006_female_Asian_59/normal.jpg
# ...                                                               ...
# 2695    ../../input/data/train/images/006954_male_Asian_19/normal.jpg
# 2696    ../../input/data/train/images/006955_male_Asian_19/normal.jpg
# 2697    ../../input/data/train/images/006956_male_Asian_19/normal.jpg
# 2698    ../../input/data/train/images/006957_male_Asian_20/normal.jpg
# 2699    ../../input/data/train/images/006959_male_Asian_19/normal.jpg
#
# [2700 rows x 9 columns]

# %%
with open( "./no_mask_api.pkl", "wb" ) as file:
    pickle.dump(no_mask_api, file)

# %% [markdown]
# ### path 수정 & age_group_api 추가

# %%
no_mask_api
# Out:
#      gender_data gender_api  gender_conf_api age_data age_group_data  age_api  \
# 0              1          1         0.999806       45              1     53.0
# 1              1          1         0.508885       52              1     52.0
# 2              0          0         0.999874       54              1     45.0
# 3              1          0         0.999967       58              1     66.0
# 4              1          0         0.746899       59              1     60.0
# ...          ...        ...              ...      ...            ...      ...
# 2695           0          0         0.999997       19              0     22.0
# 2696           0          0         0.999995       19              0     19.0
# 2697           0          0         0.999997       19              0     17.0
# 2698           0          0         0.995121       20              0     23.0
# 2699           0          0         0.999992       19              0     22.0
#
#       age_conf_api label  \
# 0         0.763184    13
# 1         0.987685    13
# 2         0.110434    13
# 3         0.489103    13
# 4         0.415534    13
# ...            ...   ...
# 2695      0.774581    12
# 2696      0.460716    12
# 2697      0.927676    12
# 2698      0.550162    12
# 2699      0.734206    12
#
#                                                                  path
# 0     ../../input/data/train/images/000001_female_Asian_45/normal.jpg
# 1     ../../input/data/train/images/000002_female_Asian_52/normal.jpg
# 2       ../../input/data/train/images/000004_male_Asian_54/normal.jpg
# 3     ../../input/data/train/images/000005_female_Asian_58/normal.jpg
# 4     ../../input/data/train/images/000006_female_Asian_59/normal.jpg
# ...                                                               ...
# 2695    ../../input/data/train/images/006954_male_Asian_19/normal.jpg
# 2696    ../../input/data/train/images/006955_male_Asian_19/normal.jpg
# 2697    ../../input/data/train/images/006956_male_Asian_19/normal.jpg
# 2698    ../../input/data/train/images/006957_male_Asian_20/normal.jpg
# 2699    ../../input/data/train/images/006959_male_Asian_19/normal.jpg
#
# [2700 rows x 9 columns]

# %%
def cleaning(x):
    x = x.replace("../../input/data/train/images/", "")
    return x

no_mask_api["path"] = no_mask_api["path"].apply(cleaning)
no_mask_api
# Out:
#      gender_data gender_api  gender_conf_api age_data age_group_data  age_api  \
# 0              1          1         0.999806       45              1     53.0
# 1              1          1         0.508885       52              1     52.0
# 2              0          0         0.999874       54              1     45.0
# 3              1          0         0.999967       58              1     66.0
# 4              1          0         0.746899       59              1     60.0
# ...          ...        ...              ...      ...            ...      ...
# 2695           0          0         0.999997       19              0     22.0
# 2696           0          0         0.999995       19              0     19.0
# 2697           0          0         0.999997       19              0     17.0
# 2698           0          0         0.995121       20              0     23.0
# 2699           0          0         0.999992       19              0     22.0
#
#       age_conf_api label                               path
# 0         0.763184    13  000001_female_Asian_45/normal.jpg
# 1         0.987685    13  000002_female_Asian_52/normal.jpg
# 2         0.110434    13    000004_male_Asian_54/normal.jpg
# 3         0.489103    13  000005_female_Asian_58/normal.jpg
# 4         0.415534    13  000006_female_Asian_59/normal.jpg
# ...            ...   ...                                ...
# 2695      0.774581    12    006954_male_Asian_19/normal.jpg
# 2696      0.460716    12    006955_male_Asian_19/normal.jpg
# 2697      0.927676    12    006956_male_Asian_19/normal.jpg
# 2698      0.550162    12    006957_male_Asian_20/normal.jpg
# 2699      0.734206    12    006959_male_Asian_19/normal.jpg
#
# [2700 rows x 9 columns]

# %%
def age_group(x):
    if x < 30:
        return 0
    elif x < 60:
        return 1
    else:
        return 2

no_mask_api["age_group_api"] = no_mask_api["age_api"].apply(age_group)
no_mask_api
# Out:
#      gender_data gender_api  gender_conf_api age_data age_group_data  age_api  \
# 0              1          1         0.999806       45              1     53.0
# 1              1          1         0.508885       52              1     52.0
# 2              0          0         0.999874       54              1     45.0
# 3              1          0         0.999967       58              1     66.0
# 4              1          0         0.746899       59              1     60.0
# ...          ...        ...              ...      ...            ...      ...
# 2695           0          0         0.999997       19              0     22.0
# 2696           0          0         0.999995       19              0     19.0
# 2697           0          0         0.999997       19              0     17.0
# 2698           0          0         0.995121       20              0     23.0
# 2699           0          0         0.999992       19              0     22.0
#
#       age_conf_api label                               path  age_group_api
# 0         0.763184    13  000001_female_Asian_45/normal.jpg              1
# 1         0.987685    13  000002_female_Asian_52/normal.jpg              1
# 2         0.110434    13    000004_male_Asian_54/normal.jpg              1
# 3         0.489103    13  000005_female_Asian_58/normal.jpg              2
# 4         0.415534    13  000006_female_Asian_59/normal.jpg              2
# ...            ...   ...                                ...            ...
# 2695      0.774581    12    006954_male_Asian_19/normal.jpg              0
# 2696      0.460716    12    006955_male_Asian_19/normal.jpg              0
# 2697      0.927676    12    006956_male_Asian_19/normal.jpg              0
# 2698      0.550162    12    006957_male_Asian_20/normal.jpg              0
# 2699      0.734206    12    006959_male_Asian_19/normal.jpg              0
#
# [2700 rows x 10 columns]

# %%
no_mask_api.columns.tolist()
# Out:
# ['gender_data',
#  'gender_api',
#  'gender_conf_api',
#  'age_data',
#  'age_group_data',
#  'age_api',
#  'age_conf_api',
#  'label',
#  'path',
#  'age_group_api']

# %%
no_mask_api_final = no_mask_api[['gender_data', 'gender_api', 'gender_conf_api',
 'age_data', 'age_group_data', 'age_api', 'age_group_api', 'age_conf_api',
 'label', 'path',
 ]]

# %%
no_mask_api_final
# Out:
#      gender_data gender_api  gender_conf_api age_data age_group_data  age_api  \
# 0              1          1         0.999806       45              1     53.0
# 1              1          1         0.508885       52              1     52.0
# 2              0          0         0.999874       54              1     45.0
# 3              1          0         0.999967       58              1     66.0
# 4              1          0         0.746899       59              1     60.0
# ...          ...        ...              ...      ...            ...      ...
# 2695           0          0         0.999997       19              0     22.0
# 2696           0          0         0.999995       19              0     19.0
# 2697           0          0         0.999997       19              0     17.0
# 2698           0          0         0.995121       20              0     23.0
# 2699           0          0         0.999992       19              0     22.0
#
#       age_group_api  age_conf_api label                               path
# 0                 1      0.763184    13  000001_female_Asian_45/normal.jpg
# 1                 1      0.987685    13  000002_female_Asian_52/normal.jpg
# 2                 1      0.110434    13    000004_male_Asian_54/normal.jpg
# 3                 2      0.489103    13  000005_female_Asian_58/normal.jpg
# 4                 2      0.415534    13  000006_female_Asian_59/normal.jpg
# ...             ...           ...   ...                                ...
# 2695              0      0.774581    12    006954_male_Asian_19/normal.jpg
# 2696              0      0.460716    12    006955_male_Asian_19/normal.jpg
# 2697              0      0.927676    12    006956_male_Asian_19/normal.jpg
# 2698              0      0.550162    12    006957_male_Asian_20/normal.jpg
# 2699              0      0.734206    12    006959_male_Asian_19/normal.jpg
#
# [2700 rows x 10 columns]

# %%
with open( "./no_mask_api_final.pkl", "wb" ) as file:
    pickle.dump(no_mask_api_final, file)
